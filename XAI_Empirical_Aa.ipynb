# %% [markdown]
# ## Ques1 - Do feature importance vary based on type of Model being used ?
# Here we discuss White-box models where we can get feature importance directly without using any explicit XAI technique as they r by design interpretable.

# %% [markdown]
# ### Dataset
#
# Dataset feature understanding for interpretation

# %% [markdown]
# ![Xnip2022-04-18_10-47-33.jpg](attachment:Xnip2022-04-18_10-47-33.jpg)

# %% [markdown]
# ###  Tree Based Models (DT & RF)

# %% [markdown]
# Why White Box ? Can be visualized as Binary tree and gives result in if-else rules.
#
# ![tr.jpg](attachment:tr.jpg)

# %% [markdown]
# ![Xnip2022-04-18_11-07-57.jpg](attachment:Xnip2022-04-18_11-07-57.jpg)

# %% [markdown]
# ### 1. Feature Importance Decision Tree
#
# Although dataset split is maintained using random seed, we still get a different answer everytime (algorithm stochasticity)

# %% [markdown]
# ![Xnip2022-04-18_11-11-31.jpg](attachment:Xnip2022-04-18_11-11-31.jpg)

# %% [markdown]
# ### 2. Feature Importance Random Forest
#
# We look at global relative importance of each feature by averaging the normalized feature
# importance across all decision trees

# %% [markdown]
# ![st.jpg](attachment:st.jpg)

# %% [markdown]
# ### Regression Based Model
#
# Y white Box ? Weights corresponsing to each feature reflect strength of relationship with target.

# %% [markdown]
# ![Xnip2022-04-18_16-29-01.jpg](attachment:Xnip2022-04-18_16-29-01.jpg)

# %% [markdown]
# ### 1. Logistic Regression Feature Importance

# %% [markdown]
# ![logistic_reg.jpg](attachment:logistic_reg.jpg)

# %% [markdown]
# ### Conclusion-
#
# Yes, Feature importance vary depending on type of model being used as different models give different top contributors.
#
# 1. Decision Tree -       **age**, Glucose_level, **bmi**, never_smoked, rural
# 2. Random Forest -       **age**, Glucose_level, **bmi**, hypertension, married/not_married
# 3. Logistic Regression - Hypertesion, children, heart_disease, **age**, **bmi**
