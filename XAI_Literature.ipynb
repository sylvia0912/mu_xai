# %% [markdown]
# # Literature for XAI

# %% [markdown]
# ![xai.jpg](attachment:xai.jpg)

# %% [markdown]
# ## 1. Survey - XAI for Tabular Data: A Survey (2016)

# %% [markdown]
# ![Xnip2022-04-16_22-21-36.jpg](attachment:Xnip2022-04-16_22-21-36.jpg)

# %% [markdown]
# 1. Model Explanation -> Approximating black-box behaviour using alternative model that is more transparent and interpretable. e.g. GAM
# 2. Model Inspection -> Provide visual/textual explanation of properties of model/outcome.e.g. PDP
# 3.Outcome Explanation -> Explain outcome given an instance of interest, how outcome was generated. e.g. LIME simple rules, SHAP

# %% [markdown]
# ## 2. Research Article - Comparison of feature importance measures as explanations for classification models (2021)

# %% [markdown]
# ![lit.jpg](attachment:lit.jpg)

# %% [markdown]
# # References -
#
# 1. Explainable AI for Tabular Data: A Survey, by - Maria Sahakyan - IEEE
#
# 2. Research Article - Comparison of feature importance measures as explanations for classification models, by Mirka Sareela - SN Applied Sciences
